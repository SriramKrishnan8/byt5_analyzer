# %%
# %load_ext autoreload
# %autoreload 2

# %%
from byt5_analyzer import Byt5Analyzer
analyzer = Byt5Analyzer()

# %%
from cli import run_byt5_text

# %%
# Word Morphological Analysis

input_text = "gacCawi"
input_encoding = "WX"
output_encoding = "roma"
mode = "mp"

run_byt5_text(analyzer, input_text, input_encoding, output_encoding, mode)
# Out:
# Byt5 Inference: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# {'input': 'gacchati',
#  'status': 'success',
#  'source': 'ByT5',
#  'raw_result': 'gacchati_gam_Tense=Pres|Mood=Ind|Person=3|Number=Sing'}

# %%
# Compound Segmentation and Morphological Analysis

input_text = "rawnaXAwamam"
input_encoding = "WX"
output_encoding = "roma"
mode = "wsmp"

run_byt5_text(analyzer, input_text, input_encoding, output_encoding, mode)
# Out:
# Byt5 Inference: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# {'input': 'ratnadhātamam',
#  'status': 'success',
#  'source': 'ByT5',
#  'raw_result': 'ratna-_ratna_Case=Cpd dhātamam_dhātama_Case=Acc|Gender=Masc|Number=Sing'}

# %%
# Sentence Segmentation and Morphological Analysis

input_text = "rAmaH vanam gacCawi"
input_encoding = "WX"
output_encoding = "roma"
mode = "wsmp"

run_byt5_text(analyzer, input_text, input_encoding, output_encoding, mode)
# Out:
# Byt5 Inference: 100%|██████████| 1/1 [00:02<00:00,  2.84s/it]
# {'input': 'rāmaḥ vanam gacchati',
#  'status': 'success',
#  'source': 'ByT5',
#  'raw_result': 'rāmaḥ_rāma_Case=Nom|Gender=Masc|Number=Sing vanam_vana_Case=Acc|Gender=Neut|Number=Sing gacchati_gam_Tense=Pres|Mood=Ind|Person=3|Number=Sing'}

# %%
# Sentence Segmentation

input_text = "agnimIde purohiwaM yajFasya xevamqwvijam . howAraM rawnaXAwamam"
input_encoding = "WX"
output_encoding = "roma"
mode = "ws"

run_byt5_text(analyzer, input_text, input_encoding, output_encoding, mode)
# Out:
# Byt5 Inference: 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# {'input': 'agnimīḍe purohitaṃ yajñasya devamṛtvijam . hotāraṃ ratnadhātamam',
#  'status': 'success',
#  'source': 'ByT5',
#  'raw_result': 'agnim īḍe purohitam yajñasya devam ṛtvijam । hotāram ratna dhātamam '}
